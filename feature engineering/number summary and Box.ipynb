# %% [markdown]
# ## 5 number summary and box plot

# %%
import numpy as np

#numimum ,maximum,median
lst_mark = [45,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74]
minimum,q1,median,q3,maximum = np.quantile(lst_mark,[0,0.25,0.50,0.7,1])

# %%
minimum,q1,median,q3,maximum
# Out:
# (np.float64(32.0),
#  np.float64(54.0),
#  np.float64(67.0),
#  np.float64(87.4),
#  np.float64(99.0))

# %%
IQR = q3-q1
print(IQR)
# Out:
# 33.400000000000006

# %%
lower_Fence = q1-1.5*(IQR)
higher_fence = q3+1.5*(IQR)

# %%
lower_Fence
# Out:
# np.float64(3.8999999999999915)

# %%
higher_fence
# Out:
# np.float64(137.5)

# %%
lst_mark = [45,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74]

# %%
import  seaborn as sns

# %%
sns.boxplot(lst_mark)
# Out:
# <Axes: >
